# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df=pd.read_csv("train.csv")

# %%
train_df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
train_df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
#import the test data
test_df=pd.read_csv("test.csv")

# %%
test_df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 127593  1004559  P00113442      M  26-35           7             B
# 127594  1004566  P00237542      M  36-45          17             C
# 127595  1004566  P00144042      M  36-45          17             C
# 127596  1004571  P00192942      M  36-45           7             C
# 127597  1004571  P00058242      M  36-45           7           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             1.0                 1.0
# ...

# %%
test_df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             1.0                 1.0
# 1                          0             0.0                 3.0
# 2                         4+             1.0                 5.0
# 3                         4+             1.0                 4.0
# 4                          1             0.0                 4.0
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
#merge the train and test data csv file
main_df=train_df.append(test_df)
# Out:
# <ipython-input-10-b54c418a4291>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   main_df=train_df.append(test_df)

# %%
main_df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 127593  1004559  P00113442      M  26-35         7.0             B
# 127594  1004566  P00237542      M  36-45        17.0             C
# 127595  1004566  P00144042      M  36-45        17.0             C
# 127596  1004571  P00192942      M  36-45         7.0             C
# 127597  1004571  P00058242      M  36-45         7.0           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# ...

# %%
main_df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
main_df.shape
# Out:
# (217952, 12)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 217952 entries, 0 to 127597
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     217952 non-null  int64
#  1   Product_ID                  217952 non-null  object
#  2   Gender                      217952 non-null  object
#  3   Age                         217952 non-null  object
#  4   Occupation                  217951 non-null  float64
#  5   City_Category               217950 non-null  object
#  6   Stay_In_Current_City_Years  217950 non-null  object
#  7   Marital_Status              217950 non-null  float64
#  8   Product_Category_1          217950 non-null  float64
#  9   Product_Category_2          150251 non-null  float64
#  10  Product_Category_3          66257 non-null   float64
#  11  Purchase                    90353 non-null   float64
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
main_df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.179520e+05  217951.000000   217950.000000       217950.000000
# mean   1.002901e+06       8.086474        0.411053            5.282390
# std    1.743304e+03       6.528499        0.492026            3.733606
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001356e+06       2.000000        0.000000            1.000000
# 50%    1.002887e+06       7.000000        0.000000            5.000000
# 75%    1.004377e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3      Purchase
# count       150251.000000        66257.000000  90353.000000
# mean             9.852074           12.654421   9292.215732
# std              5.096179            4.126041   4963.411008
# min              2.000000            3.000000    185.000000
# ...

# %%
main_df.drop(["User_ID"],axis=1,inplace=True)

# %%
main_df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17        10.0             A
# 1  P00248942      F  0-17        10.0             A
# 2  P00087842      F  0-17        10.0             A
# 3  P00085442      F  0-17        10.0             A
# 4  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
#handling Categorical Features Fender
main_df["Gender"]=main_df["Gender"].map({"F":0,"M":1})
main_df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17        10.0             A
# 1  P00248942       0  0-17        10.0             A
# 2  P00087842       0  0-17        10.0             A
# 3  P00085442       0  0-17        10.0             A
# 4  P00285442       1   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
import sklearn

# %%
from sklearn import preprocessing

label_encoder=preprocessing.LabelEncoder()

main_df["Age"]=label_encoder.fit_transform(main_df["Age"])

main_df["Age"].unique()
# Out:
# array([0, 7, 2, 5, 6, 3, 1, 4])

# %%
main_df["Age"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         7
#          ..
# 127593    2
# 127594    3
# 127595    3
# 127596    3
# 127597    3
# Name: Age, Length: 217952, dtype: int64

# %%
main_df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    0        10.0             A
# 1  P00248942       0    0        10.0             A
# 2  P00087842       0    0        10.0             A
# 3  P00085442       0    0        10.0             A
# 4  P00285442       1    7        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
main_df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
main_df["City_Category"]=label_encoder.fit_transform(main_df["City_Category"])
main_df["City_Category"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         2
#          ..
# 127593    1
# 127594    2
# 127595    2
# 127596    2
# 127597    3
# Name: City_Category, Length: 217952, dtype: int64

# %%
main_df.head(10)
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    0        10.0              0
# 1  P00248942       0    0        10.0              0
# 2  P00087842       0    0        10.0              0
# 3  P00085442       0    0        10.0              0
# 4  P00285442       1    7        16.0              2
# 5  P00193542       1    2        15.0              0
# 6  P00184942       1    5         7.0              1
# 7  P00346142       1    5         7.0              1
# 8   P0097242       1    5         7.0              1
# 9  P00274942       1    2        20.0              0
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# ...

# %%
main_df.drop("City_Category",axis=1,inplace=True)

# %%
main_df.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
main_df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         1
# Stay_In_Current_City_Years         2
# Marital_Status                     2
# Product_Category_1                 2
# Product_Category_2             67701
# Product_Category_3            151695
# Purchase                      127599
# dtype: int64

# %%
main_df.isnull().sum().sum()
# Out:
# 347002

# %%
#focus on replacing missing values
main_df["Product_Category_1"].unique()
# Out:
# array([ 3.,  1., 12.,  8.,  5.,  4.,  2.,  6., 14., 11., 13., 15.,  7.,
#        16., 18., 10., 17.,  9., nan])

# %%
main_df["Product_Category_1"].value_counts()
# Out:
# 5.0     60718
# 1.0     56104
# 8.0     45399
# 11.0     9643
# 2.0      9519
# 6.0      8105
# 3.0      7989
# 4.0      4646
# 16.0     3797
# 15.0     2491
# 13.0     2147
# 10.0     2067
# 12.0     1538
# 7.0      1530
# 18.0     1213
# 14.0      629
# 17.0      235
# 9.0       180
# Name: Product_Category_1, dtype: int64

# %%
#replace the missing values with mode
main_df["Product_Category_1"]=main_df["Product_Category_1"].fillna(main_df["Product_Category_1"].mode()[0])

# %%
main_df["Product_Category_1"].unique()
# Out:
# array([ 3.,  1., 12.,  8.,  5.,  4.,  2.,  6., 14., 11., 13., 15.,  7.,
#        16., 18., 10., 17.,  9.])

# %%
main_df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         1
# Stay_In_Current_City_Years         2
# Marital_Status                     2
# Product_Category_1                 0
# Product_Category_2             67701
# Product_Category_3            151695
# Purchase                      127599
# dtype: int64

# %%
main_df["Product_Category_2"].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
main_df["Product_Category_2"].mode()
# Out:
# 0    8.0
# Name: Product_Category_2, dtype: float64

# %%
main_df["Product_Category_2"]=main_df["Product_Category_2"].fillna(main_df["Product_Category_2"].mode()[0])

# %%
main_df["Product_Category_2"].unique()
# Out:
# array([ 8.,  6., 14.,  2., 15., 16., 11.,  5.,  3.,  4., 12.,  9., 10.,
#        17., 13.,  7., 18.])

# %%
main_df["Product_Category_3"]=main_df["Product_Category_3"].fillna(main_df["Product_Category_3"].mode()[0])

# %%
main_df["Product_Category_3"].unique()
# Out:
# array([16., 14., 17.,  5.,  4., 15.,  8.,  9., 13.,  6., 12.,  3., 18.,
#        11., 10.])

# %%
main_df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         1
# Stay_In_Current_City_Years         2
# Marital_Status                     2
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      127599
# dtype: int64

# %%
main_df["Purchase"]=main_df["Purchase"].fillna(main_df["Purchase"].mode()[0])

# %%
main_df["Purchase"].unique()
# Out:
# array([ 8370., 15200.,  1422., ...,  1049.,  9605., 19962.])

# %%
main_df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0    0        10.0                          2
# 1  P00248942       0    0        10.0                          2
# 2  P00087842       0    0        10.0                          2
# 3  P00085442       0    0        10.0                          2
# 4  P00285442       1    7        16.0                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             0.0                 3.0                 8.0                16.0
# 1             0.0                 1.0                 6.0                14.0
# 2             0.0                12.0                 8.0                16.0
# 3             0.0                12.0                14.0                16.0
# 4             0.0                 8.0                 8.0                16.0
#
#    Purchase
# 0    8370.0
# 1   15200.0
# 2    1422.0
# 3    1057.0
# 4    7969.0

# %%
main_df.shape
# Out:
# (217952, 10)

# %%
main_df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
main_df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
main_df.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
#visualizations od Age vs Purchase
sns.barplot(x="Age",y="Purchase",hue="Gender",data=main_df)
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
main_df["Occupation"].unique()
# Out:
# array([10., 16., 15.,  7., 20.,  9.,  1., 12., 17.,  0.,  3.,  4., 11.,
#         8., 19.,  2., 18.,  5., 14., 13.,  6., nan])

# %%
main_df["Occupation"].value_counts()
main_df.drop_duplicates(subset="Occupation", inplace=True)
grouped_df = main_df.groupby("Occupation")
sns.barplot(x="Occupation", y="Purchase", hue="Gender", data=main_df)
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
sns.barplot(x="Product_Category_1",y="Purchase",hue="Gender",data=main_df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
sns.barplot(x="Product_Category_2",y="Purchase",hue="Gender",data=main_df)
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
sns.barplot(x="Product_Category_3",y="Purchase",hue="Gender",data=main_df)
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
X=main_df[:-1]
y = main_df.drop(index=main_df.index[-1])

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
y["Stay_In_Current_City_Years"]=label_encoder.fit_transform(y["Stay_In_Current_City_Years"])
y["Stay_In_Current_City_Years"].unique()
# Out:
# array([2, 4, 3, 1, 0, 5])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X.shape
# Out:
# (217951, 10)

# %%
y.shape
# Out:
# (217951, 10)
